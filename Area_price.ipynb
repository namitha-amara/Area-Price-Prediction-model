# %% [raw]
# PROJECT NAME:
# AREA PRICE PREDICTION

# %%
import pandas as pd

# %%
df=pd.read_csv("areaprice071.csv")

# %%
df
# Out:
#     area   price
# 0   2600  550000
# 1   3000  565000
# 2   3200  610000
# 3   3600  680000
# 4   4000  725000
# 5   2200  520000
# 6   2400  540000
# 7   2800  555000
# 8   3100  590000
# 9   3400  650000
# 10  3700  700000
# 11  3900  715000
# 12  4200  745000
# 13  4400  770000
# 14  4600  800000

# %%
x=df[["area"]]

# %%
x
# Out:
#     area
# 0   2600
# 1   3000
# 2   3200
# 3   3600
# 4   4000
# 5   2200
# 6   2400
# 7   2800
# 8   3100
# 9   3400
# 10  3700
# 11  3900
# 12  4200
# 13  4400
# 14  4600

# %%
y=df.price

# %%
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     520000
# 6     540000
# 7     555000
# 8     590000
# 9     650000
# 10    700000
# 11    715000
# 12    745000
# 13    770000
# 14    800000
# Name: price, dtype: int64

# %% [raw]
# VISUALIZING THE DATA

# %%
import matplotlib.pyplot as plt

# %%
plt.title("AREA VS PRICE")
plt.xlabel("Area")
plt.ylabel("Price")
plt.scatter(x,y,color="violet",s=100,ec=["red","blue"])
plt.show()

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\namitha\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\namitha\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\namitha\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\namitha\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\namitha\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([124.21405864])

# %%
model.intercept_
# Out:
# 224510.77357824106

# %%
x
# Out:
#     area
# 0   2600
# 1   3000
# 2   3200
# 3   3600
# 4   4000
# 5   2200
# 6   2400
# 7   2800
# 8   3100
# 9   3400
# 10  3700
# 11  3900
# 12  4200
# 13  4400
# 14  4600

# %%
model.coef_*5000+model.intercept_
# Out:
# array([845581.06676086])

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
model.predict([[5000]])
# Out:
# array([845581.06676086])

# %%
pred=model.predict(x)

# %%
df
# Out:
#     area   price
# 0   2600  550000
# 1   3000  565000
# 2   3200  610000
# 3   3600  680000
# 4   4000  725000
# 5   2200  520000
# 6   2400  540000
# 7   2800  555000
# 8   3100  590000
# 9   3400  650000
# 10  3700  700000
# 11  3900  715000
# 12  4200  745000
# 13  4400  770000
# 14  4600  800000

# %%
plt.title("area vs price")
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(x,y,color="violet",s=100,ec=["red","blue"])
plt.plot(x,pred,color="black")
plt.show()

# %%
myarea=int(input("enter the value of area : "))
myprice=model.predict([[myarea]])
print("price is : ",myprice[0])
# Out:
# enter the value of area :  12000
# price is :  1715079.4772165308
